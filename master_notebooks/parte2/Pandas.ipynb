# %% [markdown]
# # Pandas

# %%
import pandas as pd # import pandas
import numpy as np # import numpy
import matplotlib.pyplot as plt # import libreria para plotear
pd.set_option('max_columns', 50) # maximo de columnas a mostrar cuando se muestra un pandas dataframe
# indica a python que plotee en el notebook
# %matplotlib inline

# %% [markdown]
# ## Series

# %% [markdown]
# Crear una estructura _Series_ con indice por defecto

# %%
# crear una estructura Series desde una lista arbitraria
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'])
#print s

# %%
print (s[0])
print (s[1])
print (s[2])
print (s[3])
print (s[4])
# Out:
# 7
# Heisenberg
# 3.14
# -1789710578
# Happy Eating!

# %% [markdown]
# Crear una estructura _Series_ con indicando un indice

# %%
s = pd.Series([7, 'Heisenberg', 3.14, -1789710578, 'Happy Eating!'],
              index=['A', 'Z', 'C', 'Y', 'E'])
print(s)
# Out:
# A                7
# Z       Heisenberg
# C             3.14
# Y      -1789710578
# E    Happy Eating!
# dtype: object

# %% [markdown]
# Se puede acceder a los elementos utilizando el indice

# %%
print s['A']
print s['Z']
print s['C']
print s['Y']
print s['E']

# %% [markdown]
# Se puede acceder a los elementos igualmente utilizando el indice numerico

# %%
print s[0]
print s[1]
print s[2]
print s[3]
print s[4]

# %% [markdown]
# Tambien se puede convertir un diccionario a una estructura _Series_

# %%
d = {'Chicago': 1000, 'New York': 1300, 'Portland': 900, 'San Francisco': 1100,
     'Austin': 450, 'Boston': None}
cities = pd.Series(d)
cities
# Out:
# Austin            450.0
# Boston              NaN
# Chicago          1000.0
# New York         1300.0
# Portland          900.0
# San Francisco    1100.0
# dtype: float64

# %% [markdown]
# Se puede usar el indice para acceder a la estructura

# %%
print cities['Chicago']

# %%
print cities[['Chicago', 'Portland', 'San Francisco']]

# %% [markdown]
# O se puede utilizar indexado booleano (como en numpy) para el acceso

# %%
print (cities[cities < 1000])
# Out:
# Austin      450.0
# Portland    900.0
# dtype: float64

# %% [markdown]
# Que ocurrio arriba? cities < 1000 devuelve un _Series_ de valores _True/False_ que depues se pasan a la estructura _Series_ idexando los items que corresponden con los valore _True_

# %%
less_than_1000 = cities < 1000
print(less_than_1000)
print('\n')
print(cities[less_than_1000])
# Out:
# Austin            True
# Boston           False
# Chicago          False
# New York         False
# Portland          True
# San Francisco    False
# dtype: bool
#
#
# Austin      450.0
# Portland    900.0
# dtype: float64

# %% [markdown]
# Se puede cambiar el valor de _Series_

# %%
# cambiando valores basado en el indice
print('Old value:', cities['Chicago'])
cities['Chicago'] = 1400
print('New value:', cities['Chicago'])
# Out:
# Old value: 1000.0
# New value: 1400.0

# %%
# cambiando valores usando logica booleana
print(cities[cities < 1000])
print('\n')
cities[cities < 1000] = 750

print (cities[cities < 1000])
# Out:
# Austin      450.0
# Portland    900.0
# dtype: float64
#
#
# Austin      750.0
# Portland    750.0
# dtype: float64

# %% [markdown]
# Se puede comprobar si un item esta contenido en la _Series_

# %%
print('Seattle' in cities)
print('San Francisco' in cities)

# %% [markdown]
# Se pueden hacer operaciones aritmeticas

# %%
# dividir por 3
print(cities / 3)
# Out:
# Austin           250.000000
# Boston                  NaN
# Chicago          466.666667
# New York         433.333333
# Portland         250.000000
# San Francisco    366.666667
# dtype: float64

# %%
# elevar al cuadrado
print (np.square(cities))
# Out:
# Austin            562500.0
# Boston                 NaN
# Chicago          1960000.0
# New York         1690000.0
# Portland          562500.0
# San Francisco    1210000.0
# dtype: float64

# %%
print(cities[['Chicago', 'New York', 'Portland']])
print('\n')
print(cities[['Austin', 'New York']])
print('\n')
print(cities[['Chicago', 'New York', 'Portland']] + cities[['Austin', 'New York']])
# Out:
# Chicago     1400.0
# New York    1300.0
# Portland     750.0
# dtype: float64
#
#
# Austin       750.0
# New York    1300.0
# dtype: float64
#
#
# Austin         NaN
# Chicago        NaN
# New York    2600.0
# Portland       NaN
# dtype: float64

# %% [markdown]
# Nota que Austin, Chicago y Portlan no se encontraron en ambas _Series_, fueron retornadas con valores NULL/NaN.
#
# Se puede comprobar si un valor es NULL a traves de _isnull_ y _notnull_ .

# %%
# devuelve una Serie booleana diciendo cuales no son Null
print (cities.notnull())
# Out:
# Austin            True
# Boston           False
# Chicago           True
# New York          True
# Portland          True
# San Francisco     True
# dtype: bool

# %% [markdown]
# Se puede usar logica booleana para indexar las ciudades que no son NULL

# %%
# usando logica booleana para indexar las ciudades que no son NULL
print(cities.isnull())
print('\n')
print(cities[cities.isnull()])
# Out:
# Austin           False
# Boston            True
# Chicago          False
# New York         False
# Portland         False
# San Francisco    False
# dtype: bool
#
#
# Boston   NaN
# dtype: float64

# %% [markdown]
# ## Dataframe

# %% [markdown]
# Puedes pensar en un _Dataframe_ como una estructura de datos tabular que almacena cualquier clase de informacion en filas y columnas. Por hacer un simil, uno podria pensar en un hoja de Excel como algo similar (no es lo mismo pero se parecen).

# %% [markdown]
# En realidad un _Dataframe_ no es mas que un conjunto de estructuras _Series_ que comparten un mismo indice. Por defecto el indice va de 0 hasta N-1 donde N es el numero de filas del _Dataframe_. Se puede crear de forma manual un _Dataframe_ como sigue.

# %%
data = {'year': [2010, 2011, 2012, 2011, 2012, 2010, 2011, 2012],
        'team': ['Barca', 'Barca', 'Barca', 'Madrid', 'Madrid', 'Mallorca', 'Mallorca', 'Mallorca'],
        'wins': [11, 8, 10, 15, 11, 6, 10, 4],
        'losses': [5, 8, 6, 1, 5, 10, 6, 12]}
football = pd.DataFrame(data, columns=['year', 'team', 'wins', 'losses'])
football.head()
# Out:
#    year    team  wins  losses
# 0  2010   Barca    11       5
# 1  2011   Barca     8       8
# 2  2012   Barca    10       6
# 3  2011  Madrid    15       1
# 4  2012  Madrid    11       5

# %% [markdown]
# Es mucho mas habitual leer un _Dataframe_ desde un fichero de texto _csv_ con la funcion de _Pandas_ _pd.read\_csv_

# %%
nuc_pob = pd.read_csv('NucleosPoblacion.csv')

# %% [markdown]
# La funcion _head()_ nos permite explorar las primeras filas del _Dataframe_ y la funcion _tail()_ las ultimas.

# %%
nuc_pob.head() # primeras lineas del dataframe
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %%
nuc_pob.tail() # ultimas lineas del dataframe
# Out:
#      FID  OBJECTID                           Texto  Poblacion  CodMun  \
# 847  847       848             Infante Juan Manuel    14192.0   30030
# 848  848       849           Santa Maria de Gracia    13349.0   30030
# 849  849       850                    Vista Alegre    15208.0   30030
# 850  850       851  Poligono Sta M de Benquerencia    19177.0   45168
# 851  851       852                            Grao    16367.0   12040
#
#                                       Municipio  CodProvin  \
# 847                                      Murcia         30
# 848                                      Murcia         30
# 849                                      Murcia         30
# 850                                      Toledo         45
# 851  Castellón de la Plana/Castelló de la Plana         12
#
#               Provincia         X          Y
# 847              Murcia -1.124304  37.979033
# 848              Murcia -1.202069  37.984024
# 849              Murcia -1.130564  37.995715
# 850              Toledo -3.948364  39.866699
# 851  Castelló/Castellón  0.012911  39.973568

# %% [markdown]
# Al igual que en el modulo _Numpy_ se pueden realizar operaciones de forma muy sencilla con el indexado booleano

# %%
print ('Mean Poblacion', nuc_pob['Poblacion'].mean())
print ('STD Poblacion', nuc_pob['Poblacion'].std())
print ('Min Poblacion', nuc_pob['Poblacion'].min())
print ('Max Poblacion', nuc_pob['Poblacion'].max())
# Out:
# Mean Poblacion 45710.85680751174
# STD Poblacion 140598.14339650262
# Min Poblacion 10037.0
# Max Poblacion 3273049.0

# %% [markdown]
# Y se pueden combinar las operaciones para obtener resultados mas interesantes

# %%
nuc_pob[nuc_pob['Poblacion'] >50000].head()
# Out:
#     FID  OBJECTID                       Texto  Poblacion  CodMun  \
# 2     2         3                    Arrecife    58156.0   35004
# 9     9        10  Las Palmas de Gran Canaria   383308.0   35016
# 13   13        14     Santa Lucía de Tirajana    64845.0   35022
# 16   16        17                       Telde   100900.0   35026
# 22   22        23                       Arona    79377.0   38006
#
#                      Municipio  CodProvin               Provincia          X  \
# 2                     Arrecife         35              Las Palmas -13.551451
# 9   Las Palmas de Gran Canaria         35              Las Palmas -15.413387
# 13     Santa Lucía de Tirajana         35              Las Palmas -15.540409
# 16                       Telde         35              Las Palmas -15.416666
# 22                       Arona         38  Santa Cruz de Tenerife -16.679684
#
#             Y
# 2   28.960649
# 9   28.099775
# 13  27.911841
# 16  27.994202
# 22  28.099518

# %%
nuc_pob[(nuc_pob['Poblacion'] >50000) & (nuc_pob['Provincia'] == 'Granada') ].head()
# Out:
#      FID  OBJECTID    Texto  Poblacion  CodMun Municipio  CodProvin Provincia  \
# 272  272       273  Granada   239154.0   18087   Granada         18   Granada
# 278  278       279   Motril    60884.0   18140    Motril         18   Granada
#
#             X          Y
# 272 -3.600019  37.176419
# 278 -3.521234  36.745746

# %% [markdown]
# Ordenar los valores en base a una columna nunca fue tan sencillo

# %%
nuc_pob.sort_values('Poblacion', ascending = False).head() # si pones ascending = True los ordena en orden ascendente
# Out:
#      FID  OBJECTID      Texto  Poblacion  CodMun  Municipio  CodProvin  \
# 355  355       356     Madrid  3273049.0   28079     Madrid         28
# 623  623       624  Barcelona  1619337.0    8019  Barcelona          8
# 561  561       562   Valencia   809267.0   46250   Valencia         46
# 492  492       493    Sevilla   704198.0   41091    Sevilla         41
# 591  591       592   Zaragoza   675121.0   50297   Zaragoza         50
#
#              Provincia         X          Y
# 355             Madrid -3.703797  40.416630
# 623          Barcelona  2.176349  41.384247
# 561  València/Valencia -0.375657  39.475344
# 492            Sevilla -5.992514  37.386205
# 591           Zaragoza -0.879287  41.656457

# %% [markdown]
# Puedes resetear el indice para que despues de ordenarlos cambie. Observa como cambia el indice y ahora se ha reseteado y aparece el nuevo indice con las ciudades ordenadas.

# %%
# Esto puede servirte muy util para ordenar y encontrar luego posiciones
nuc_pob.sort_values('Poblacion', ascending = False).reset_index(drop=True).head() # con drop nos deshacemos del antiguo indice
# Out:
#    FID  OBJECTID      Texto  Poblacion  CodMun  Municipio  CodProvin  \
# 0  355       356     Madrid  3273049.0   28079     Madrid         28
# 1  623       624  Barcelona  1619337.0    8019  Barcelona          8
# 2  561       562   Valencia   809267.0   46250   Valencia         46
# 3  492       493    Sevilla   704198.0   41091    Sevilla         41
# 4  591       592   Zaragoza   675121.0   50297   Zaragoza         50
#
#            Provincia         X          Y
# 0             Madrid -3.703797  40.416630
# 1          Barcelona  2.176349  41.384247
# 2  València/Valencia -0.375657  39.475344
# 3            Sevilla -5.992514  37.386205
# 4           Zaragoza -0.879287  41.656457

# %% [markdown]
# # Ejercicios

# %% [markdown]
# 1 - Carga el fichero 'NucleosPoblacion.csv' explora con las funciones _head_ y _tail_ el principio y el final.

# %%
nuc_pob = pd.read_csv('NucleosPoblacion.csv')

# %% [markdown]
# 2 - Cual es la ciudad mas poblada?

# %%
nuc_pob.sort_values('Poblacion', ascending=False)

# %% [markdown]
# 3 - Que posicion ocupa Granada en las mas pobladas?. La funcion _sort_values puede ayudarte en tu cometido

# %%
gran = nuc_pob.sort_values('Poblacion', ascending=False)
gran[gran['Municipio']=='Granada']
# Out:
#      FID  OBJECTID    Texto  Poblacion  CodMun Municipio  CodProvin Provincia  \
# 272  272       273  Granada   239154.0   18087   Granada         18   Granada
#
#             X          Y
# 272 -3.600019  37.176419

# %% [markdown]
# 4 - Escribe el nombre de los 10 municipios con menor poblacion

# %%
pob = nuc_pob.sort_values('Poblacion', ascending = True).reset_index(drop=True)[:10]
pob[['Poblacion', 'Texto']]
# Out:
#   File "<ipython-input-67-a5fdcc02e022>", line 1
#     nuc_pob[(nuc_pob['Poblacion']>50000) &&
#                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# 5 - Cuantos municipios en Extremadura tienen mas de 5000 habitantes?

# %%
nuc_pob[(nuc_pob['Poblacion']>50000) & 
        ((nuc_pob['Provincia']=='Badajoz') | 
       (nuc_pob['Provincia']=='Cáceres'))]
# Out:
#     FID  OBJECTID    Texto  Poblacion  CodMun Municipio  CodProvin Provincia  \
# 42   42        43  Badajoz   150376.0    6015   Badajoz          6   Badajoz
# 43   43        44   Mérida    57127.0    6083    Mérida          6   Badajoz
# 48   48        49  Cáceres    94179.0   10037   Cáceres         10   Cáceres
#
#            X          Y
# 42 -6.970997  38.878743
# 43 -6.344172  38.917388
# 48 -6.371211  39.473168

# %% [markdown]
# 6 - ¿Cuál es el municipio situado más al Norte? (Usar el valor de la coordenada "Y" que representa la latitud en grados). Proporcione también la provincia a la que pertenece y su población.

# %%
nuc_pob[nuc_pob['Y'] == nuc_pob['Y'].max()]['Municipio']
# Out:
# 104    Viveiro
# Name: Municipio, dtype: object

# %% [markdown]
# 7 - ¿Cual es el municipio de la provincia de Granada situado más al Este?. ¿Cual es el situado más al Oeste?.

# %%
a = nuc_pob[(nuc_pob['Provincia']=='Granada')]
a[(a['X'] == a['X'].max())]['Municipio']
a[(a['X'] == a['X'].min())]['Municipio']
# Out:
# 276    Loja
# Name: Municipio, dtype: object

# %% [markdown]
# 8 - ¿Cuántos Municipios hay en un radio de 5 grados de la ciudad de Barcelona?.

# %%
X_bcn = nuc_pob[nuc_pob['Municipio'] == 'Barcelona'].X.iloc[0]
Y_bcn = nuc_pob[nuc_pob['Municipio'] == 'Barcelona'].Y.iloc[0]


nuc_pob[(nuc_pob['X']<X_bcn+5) & (nuc_pob['X']>X_bcn-5) &
       (nuc_pob['Y']<Y_bcn+5) & (nuc_pob['Y']>Y_bcn-5)]
# Out:
#      FID  OBJECTID                  Texto  Poblacion  CodMun  \
# 155  155       156                La Roda    16299.0    2069
# 156  156       157          Villarrobledo    26686.0    2081
# 157  157       158               Albatera    11821.0    3005
# 158  158       159            Alcoy/Alcoi    61417.0    3009
# 159  159       160         L'Alfàs del Pi    21332.0    3011
# 160  160       161       Alacant/Alicante   334418.0    3014
# 161  161       162               Almoradí    19598.0    3015
# 162  162       163                  Altea    24006.0    3018
# 163  163       164                   Aspe    20360.0    3019
# 164  164       165               Benidorm    71198.0    3031
# 165  165       166      Callosa de Segura    18008.0    3049
# 166  166       167            El Campello    26941.0    3050
# 167  167       168               Castalla    10513.0    3053
# 170  170       171        Vitoria-Gasteiz   238247.0    1059
# 171  171       172               Albacete   170475.0    2003
# 172  172       173                Almansa    25654.0    2009
# 173  173       174                Caudete    10450.0    2025
# 174  174       175                 Hellín    31109.0    2037
# 175  175       176             Cocentaina    11534.0    3056
# 176  176       177             Crevillent    28738.0    3059
# 177  177       178              Elche/Elx   230822.0    3065
# 178  178       179                   Elda    54815.0    3066
# 179  179       180   Guardamar del Segura    16423.0    3076
# 180  180       181                    Ibi    23861.0    3079
# 181  181       182        Monóvar/Monòver    12928.0    3089
# 182  182       183               Mutxamel    23066.0    3090
# 183  183       184                Novelda    27104.0    3093
# 184  184       185               La Nucia    18225.0    3094
# 185  185       186               Orihuela    87113.0    3099
# 186  186       187                   Pego    11208.0    3102
# ..   ...       ...                    ...        ...     ...
# 816  816       817              La Cañada    11401.0   46190
# 817  817       818              El Puerto    41406.0   46220
# 818  818       819            Monte Vedat    11663.0   46244
# 819  819       820    Benimamet-Beniferri    14328.0   46250
# 823  823       824            Jávea/Xàbia    31909.0    3082
# 824  824       825                Teulada    14778.0    3128
# 825  825       826            Santa Ponça    11033.0    7011
# 826  826       827              S' Arenal    10242.0    7031
# 827  827       828            Pont d'inca    18565.0    7036
# 828  828       829   Es Coll De'n Rabassa    10601.0    7040
# 829  829       830            Sant Agustí    15211.0    7040
# 830  830       831              Sa Vileta    23356.0    7040
# 831  831       832        Platja de Palma    11747.0    7040
# 832  832       833  Santa Eulalia del Río    16514.0    7054
# 833  833       834               Eixample    10545.0    8159
# 834  834       835               Mira-Sol    11928.0    8205
# 835  835       836           Les Roquetes    11624.0    8231
# 836  836       837      Segur de Calafell    11765.0   43037
# 837  837       838   Sant Pere I Sant Pau    16137.0   43148
# 838  838       839             Torreforta    23443.0   43148
# 840  840       841         Ciudad Quesada    15607.0    3113
# 841  841       842           Marina-Oasis    10196.0    3118
# 843  843       844          San Cristobal    12790.0   30024
# 844  844       845               San Jose    11905.0   30024
# 845  845       846              San Mateo    10746.0   30024
# 846  846       847              El Carmen    21879.0   30030
# 847  847       848    Infante Juan Manuel    14192.0   30030
# 848  848       849  Santa Maria de Gracia    13349.0   30030
# 849  849       850           Vista Alegre    15208.0   30030
# 851  851       852                   Grao    16367.0   12040
#
#                                       Municipio  CodProvin  \
# 155                                     La Roda          2
# 156                               Villarrobledo          2
# 157                                    Albatera          3
# 158                                 Alcoy/Alcoi          3
# 159                              L'Alfàs del Pi          3
# 160                            Alacant/Alicante          3
# 161                                    Almoradí          3
# 162                                       Altea          3
# 163                                        Aspe          3
# 164                                    Benidorm          3
# 165                           Callosa de Segura          3
# 166                                 El Campello          3
# 167                                    Castalla          3
# 170                             Vitoria-Gasteiz          1
# 171                                    Albacete          2
# 172                                     Almansa          2
# 173                                     Caudete          2
# 174                                      Hellín          2
# 175                                  Cocentaina          3
# 176                                  Crevillent          3
# 177                                   Elche/Elx          3
# 178                                        Elda          3
# 179                        Guardamar del Segura          3
# 180                                         Ibi          3
# 181                             Monóvar/Monòver          3
# 182                                    Mutxamel          3
# 183                                     Novelda          3
# 184                                    La Nucia          3
# 185                                    Orihuela          3
# 186                                        Pego          3
# ..                                          ...        ...
# 816                                     Paterna         46
# 817                              Sagunto/Sagunt         46
# 818                                     Torrent         46
# 819                                    Valencia         46
# 823                                 Jávea/Xàbia          3
# 824                                     Teulada          3
# 825                                      Calvià          7
# 826                                   Llucmajor          7
# 827                                    Marratxí          7
# 828                                       Palma          7
# 829                                       Palma          7
# 830                                       Palma          7
# 831                                       Palma          7
# 832                       Santa Eulalia del Río          7
# 833                           Parets del Vallès          8
# 834                       Sant Cugat del Vallès          8
# 835                          Sant Pere de Ribes          8
# 836                                    Calafell         43
# 837                                   Tarragona         43
# 838                                   Tarragona         43
# 840                                     Rojales          3
# 841                               San Fulgencio          3
# 843                                       Lorca         30
# 844                                       Lorca         30
# 845                                       Lorca         30
# 846                                      Murcia         30
# 847                                      Murcia         30
# 848                                      Murcia         30
# 849                                      Murcia         30
# 851  Castellón de la Plana/Castelló de la Plana         12
#
#               Provincia         X          Y
# 155            Albacete -2.159248  39.207065
# 156            Albacete -2.607143  39.267558
# 157    Alacant/Alicante -0.873187  38.178862
# 158    Alacant/Alicante -0.473184  38.698369
# 159    Alacant/Alicante -0.102600  38.580095
# 160    Alacant/Alicante -0.483183  38.345487
# 161    Alacant/Alicante -0.792017  38.109780
# 162    Alacant/Alicante -0.051442  38.598925
# 163    Alacant/Alicante -0.768491  38.345773
# 164    Alacant/Alicante -0.130685  38.534271
# 165    Alacant/Alicante -0.879339  38.122581
# 166    Alacant/Alicante -0.400865  38.427547
# 167    Alacant/Alicante -0.670265  38.596576
# 170               Álava -2.672757  42.850588
# 171            Albacete -1.855747  38.995881
# 172            Albacete -1.094147  38.869688
# 173            Albacete -0.988691  38.705730
# 174            Albacete -1.703449  38.512190
# 175    Alacant/Alicante -0.440221  38.745412
# 176    Alacant/Alicante -0.808553  38.248814
# 177    Alacant/Alicante -0.697756  38.267417
# 178    Alacant/Alicante -0.796110  38.478789
# 179    Alacant/Alicante -0.654770  38.089881
# 180    Alacant/Alicante -0.575895  38.622644
# 181    Alacant/Alicante -0.837805  38.437216
# 182    Alacant/Alicante -0.437584  38.423744
# 183    Alacant/Alicante -0.765398  38.386064
# 184    Alacant/Alicante -0.122897  38.617616
# 185    Alacant/Alicante -0.946646  38.085741
# 186    Alacant/Alicante -0.118032  38.842017
# ..                  ...       ...        ...
# 816   València/Valencia -0.488275  39.525355
# 817   València/Valencia -0.215318  39.660566
# 818   València/Valencia -0.493094  39.423659
# 819   València/Valencia -0.405382  39.496237
# 823    Alacant/Alicante  0.162277  38.785672
# 824    Alacant/Alicante  0.102308  38.729117
# 825       Illes Balears  2.466745  39.506262
# 826       Illes Balears  2.753480  39.502268
# 827       Illes Balears  2.693164  39.596734
# 828       Illes Balears  2.696282  39.549438
# 829       Illes Balears  2.599665  39.551849
# 830       Illes Balears  2.626224  39.591134
# 831       Illes Balears  2.731277  39.529250
# 832       Illes Balears  1.529107  38.983836
# 833           Barcelona  2.222967  41.558910
# 834           Barcelona  2.052824  41.466661
# 835           Barcelona  1.756806  41.227851
# 836           Tarragona  1.608391  41.194174
# 837           Tarragona  1.252699  41.139067
# 838           Tarragona  1.218093  41.118991
# 840    Alacant/Alicante -0.721333  38.067826
# 841    Alacant/Alicante -0.692970  38.136116
# 843              Murcia -1.695129  37.681182
# 844              Murcia -1.703197  37.668545
# 845              Murcia -1.697629  37.674396
# 846              Murcia -1.130713  37.978180
# 847              Murcia -1.124304  37.979033
# 848              Murcia -1.202069  37.984024
# 849              Murcia -1.130564  37.995715
# 851  Castelló/Castellón  0.012911  39.973568
#
# [391 rows x 10 columns]

# %% [markdown]
# 9 - Obtenga la media, mediana, desviación estándar, valor máximo y valor mínimo de la población de los municipios de la provincia de Granada
